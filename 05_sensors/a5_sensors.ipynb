# %% [markdown]
# # Assignment 5 - Sensors in ROS
#
# *5 points*

# %% [markdown]
# ### Task 1 - Robotic Sensing: LiDAR Utility, Limitations, and Error Handling (2 Pts)
#
# In this section, you will evaluate the practical and theoretical challenges of sensor-based navigation. Imagine your turtle robot is equipped with a fixed 1D LiDAR as its primary exteroceptive sensor.
#
# As the programmer, address the following points in a critical analysis:
#
# #### 1. LiDAR Utility and Constraints
# * **Application:** What is the primary use of a 1D LiDAR in a differential drive robot? And which sensors are appropriate for tracking the robot pose?
# * **Limitations:** Identify at least three physical or environmental scenarios where a 1D LiDAR will fail.
# * **Mitigation:** Which additional sensor modality would you integrate to overcome these "blind spots," and how would it specifically help?
#
# #### 2. Error Analysis and Denoising
# * **Systematic vs. Random Errors:** Distinguish between these two types of errors.
# * **Error Removal:** Illustrate a technique to remove **Random Errors** versus a technique for **Systematic Errors**.
# * **Calibration:** Clearly define which of these two processes is formally known as **Calibration**.
#
# **Provide your comprehensive solution in a txt file called task1.txt.**

# %% [markdown]
# ### Task 2 - Environment mapping in Gazebo with LiDaR sensors on Turtle robot ( 3 Pts )
#
# In Assignment2, you will navigate with the turtle robot in a virtual gazebo environment, build the map and then use the map to plan navigation. **Put your results in a folder called task2_results.**
#
# 1. Provide the generated map file in environment_map.yaml (2Pts)
#
# 2. Test navigation planning based on the map and traces of execution (1Pt)
#
# [Open the Sensors Exercise in Binder](https://binder.intel4coro.de/v2/gh/IntEL4CoRo/iis-exercises/dev?urlpath=lab%2Ftree%2F03_sensors%2Foffice.ipynb)
#
# ![Navigation in Gazebo](imgs/img.png)

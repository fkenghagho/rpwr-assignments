# %% [markdown]
# # Assignment 1: Setup
# *3 points*

# %% [markdown]
# Welcome to assignment 1 of the Robot Programming with ROS course.

# %% [markdown]
# In this assignment we will set up your PC for the next assignments.

# %% [markdown]
# And you will learn basics about Linux and Python.

# %% [markdown]
# After this assignment you will understand how to
# * set up a git repository
# * navigate in a bash terminal
# * write simple python code

# %% [markdown]
# ## Part 1 - Git

# %% [markdown]
#  ### Installation

# %% [markdown]
# Git provides version-control of changing code. A Git repository is a storage place for code.
#
# With Git it is easy to manage group projects and keep track of changes.
#
# https://git-scm.com/book/en/v2/Getting-Started-Installing-Git

# %% [markdown]
# Using Git via command line interface (CLI) provides the best experience to understand how it works.
#
# There are also Git clients with a GUI.
#
# This lecture will only cover the CLI commands for Git.

# %% [markdown]
# ### GitHub setup

# %% [markdown]
# Create an account on GitHub if you don't have one: https://github.com/
#
# Create a new repository, call it **rpwr-assignments**
#
# Make it private.
#
# In project *Settings* ->  *Collaborators* add as collaborator:
# * *Franklin Kenghagho (fkenghagho)*

# %% [markdown]
# Learn about SSH Keys and Personal Access Tokens (PATs):
#
# https://docs.github.com/en/authentication/connecting-to-github-with-ssh
#
# By [adding a new SSH key to your GitHub account](https://docs.github.com/en/authentication/connecting-to-github-with-ssh/adding-a-new-ssh-key-to-your-github-account) you create a key-lock pair from your PC to your GitHub account.
#
# But note that you can also use https protocol with username + Personal Access Token (PAT) authentification. You can a PAT through **Go to Settings > Developer Settings > Personal access tokens > Tokens (classic) > Select Scopes: Check the box for repo**.

# %% [markdown]
# To avoid entering your credentials at every push, save them:
#
# `git config --global credential.helper store`
#
# You will be prompted once for your credential and never again.

# %% [markdown]
# 1. On your PC, choose where to put the lectures project.
#
# `cd into/the/desired/directory`

# %% [markdown]
# 2. Download (clone) the course material:
#
# `git clone https://github.com/fkenghagho/rpwr-assignments.git`

# %% [markdown]
# 3. Change directory (cd) into the downloaded folder
#
# `cd rpwr-assignments`

# %% [markdown]
# 4. Define a remote target with the address of your new GitHub repo.
#
# Replace **YOUR_GITHUB_USERNAME** in the following command **if your using ssh**.
#
# `git remote add my git@github.com:YOUR_GITHUB_USERNAME/rpwr-assignments.git`
#
# If you ar using https, do this:
#
# `git remote add my https://github.com/YOUR_GITHUB_USERNAME/rpwr-assignments.git`

# %% [markdown]
# ![GIT](imgs/git.png)

# %% [markdown]
# 5. Upload the files to your new GitHub repository:
#
# `git push -u my main`

# %% [markdown]
# Now check your own repository on GitHub. It should have a new commit!

# %% [markdown]
# For every new assignment, the workflow will stay the same:
# * **pull** the latest change from the *fkenghagho/rpwr-assignments* repository
# * change the files locally
# * **add** the files you want to submit for the new update
# * **commit** the update and summarize the changes done
# * **push** the changed files to your remote repository on GitHub

# %% [markdown]
# ### Submit your solution
#
# After you have finished the git setup, you can view the config file under `rpwr-assignments/.git/config`. Here you can see the remote target you created earlier. Copy the config file and paste it here as the solution.

# %% [markdown]
# ```
# # Your config file:
#
#
#
# ```

# %% [markdown]
# ## Part 2 - Linux
#
#
# Linux describes a style of operating systems. Robot software runs primarily on Linux systems.
#
# We have provided a Linux machine for you.
#
# Go to https://binder.intel4coro.de/v2/gh/artnie/pycram/binder
#
# From the Launcher, open a new Terminal.
#
# Follow the following tutorial https://ubuntu.com/tutorials/command-line-for-beginners#1-overview

# %% [markdown]
# ### Exercise 1 - Python and Bash Commands (1 Point)
#
# Drag & Drop the `into_the_dungeon.zip` folder from you local repository into Jupyter. The following code will unzip it:

# %%
import zipfile as zf
files = zf.ZipFile("into_the_dungeon.zip", 'r')
files.extractall('.')
files.close()

# %% [markdown]
# 1. Open a new terminal and `cd into_the_dungeon`, then explore it using the command line. Please note that some files might be hidden.
#
# 2. After you have found all the treasures, check your `backpack`. It should be filled now.
#
# 3. Run the command `history 50` and then save the screenshot in the folder **into_the_dungeon**.
#
# 4. Zip the whole folder with your solution again (`into_the_dungeon_solution.zip`).
#
# 5. Download the zip file (`into_the_dungeon_solution.zip`) to your local repository.
#
# 6. Submit your solution to your GitHub repository

# %% [markdown]
# ### Exercise 2 - Checking ROS2 (2 Points)
#
# 1. After installing Linux and ROS on your local machine, try the following command in the same terminal and take a screenshot as result of your execution in a folder called **01_git-linux-python/ros-command-results**. (1 Point)
#
# `source /opt/ros/jazzy/setup.bash`
#
# `ros2 --version`
#
# `printenv | grep ROS`
#
# `ros2 pkg list | grep demo_nodes`
#
# 2. Now, open two terminal and run `source /opt/ros/jazzy/setup.bash` in every terminal. On the first terminal run `ros2 run demo_nodes_cpp talker` and on the second terminal run `ros2 run demo_nodes_py listener`. Then switch the order and delays in which both commands are executed. (1 Point)
#
# - Take screenshots of your executions with appropriate naming.
# - Describe the empirical relation between both commands. Make use of a test file called **01_git-linux-python/ros-command-results/textual-answers.txt** to report your answers.

# %% [markdown]
# ### Submit your solution
#
# To submit your solution, go to your local repository
#
# `cd to/your/local/repository/rpwr-assignments`
#
# Get the latest update from the origin repository
#
# `git pull origin`
#
# Specify which files you want to submit:
#
# `git add into_the_dungeon_solution.zip`
#
# Wrap it up as one update, and give it a thoughtful description
#
# `git commit -m "I should change this message to something meaningful."`
#
# Push the new commit to your remote GitHub repository
#
# `git push`
#
# Go to your repository on GitHub and check, if commit is really pushed.
